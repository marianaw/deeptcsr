# %%
from SurvSet.data import SurvLoader

# %%
import pandas as pd

# %%
loader = SurvLoader()

# %%
df = loader.df_ds[loader.df_ds.is_td]

# %%
df
# Out:
#             ds  is_td     n  n_fac  n_ohe  n_num
# 11   epileptic   True  1286      3      3      2
# 28       heart   True   172      2      2      2
# 58  heartvalve   True   984     12     16      7
# 59       Rossi   True  1405      8     26      1
# 63         csl   True  2481      2      2      4
# 65        aids   True  1405      4      4      1
# 69     oldmort   True  6495      5     11      2

# %%
df, ref = loader.load_dataset(ds_name='Rossi').values()

# %%
len(df)
# Out:
# 1405

# %%
df.head()
# Out:
#    pid  event  time  time2  num_age fac_fin fac_race fac_wexp      fac_mar  \
# 0    1      1     0     20       27      no    black       no  not married
# 1    2      0     0      9       18      no    black       no  not married
# 2    2      0     9     14       18      no    black       no  not married
# 3    2      1    14     17       18      no    black       no  not married
# 4    3      0     0     16       19      no    other      yes  not married
#
#   fac_paro fac_prio fac_educ fac_emp
# 0      yes        3        3       0
# 1      yes        8        4       0
# 2      yes        8        4       1
# 3      yes        8        4       0
# 4      yes       13        3       0

# %%
groups = df.groupby('pid').agg({'pid':'count'})

# %%
groups.pid.max()
# Out:
# 10

# %%
len(groups)
# Out:
# 432

# %%
path = '/Users/mariana/Documents/projects/Huawei/SurvanData/kkbox-churn-prediction-challenge/data/churn_comp_refresh/user_logs_v2.csv'
df = pd.read_csv(path)

# %%
df.columns
# Out:
# Index(['msno', 'date', 'num_25', 'num_50', 'num_75', 'num_985', 'num_100',
#        'num_unq', 'total_secs'],
#       dtype='object')

# %%
delta_counts = df.groupby('msno').agg({'num_50': 'count'})

# %%
len(delta_counts)
# Out:
# 1103894

# %%
delta_counts.num_50.head()
# Out:
# msno
# +++IZseRRiQS9aaSkH6cMYU6bGDcxUieAi/tH67sC5s=    26
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=    31
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=    28
# +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=    21
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=    29
# Name: num_50, dtype: int64

# %%
df.columns
# Out:
# Index(['msno', 'date', 'num_25', 'num_50', 'num_75', 'num_985', 'num_100',
#        'num_unq', 'total_secs'],
#       dtype='object')
